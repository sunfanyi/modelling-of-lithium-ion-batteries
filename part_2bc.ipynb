# %%
import os
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

try:  # if running with Google Colab
    from google.colab import drive
    drive.mount('/content/drive')

    import sys
    # the location where you saved the tools.py and csv files
    drive_dir = '/content/drive/My Drive/Colab Notebooks/FCTT 3'
    sys.path.insert(0, drive_dir)

    data_dir = os.path.join(drive_dir, 'battery_experimental_data')
    fit_res_dir = os.path.join(drive_dir, 'fitting_results')
except:  # if running locally
    data_dir = os.path.abspath('battery_experimental_data')
    fit_res_dir = os.path.abspath('fitting_results')
    
from tools import *

# %% [markdown]
# ## Load data

# %% [markdown]
# Extract in an array of numpy arrays. Now we add one more dimension, where the first dimension represents the temperature, i.e., [3, N].
#
# For t, I and V_actual for each temperature, pad them with constant values to the same length so that they can be saved as arrays, which is easier for later calculation.

# %%
SOC_OCV_data = pd.read_csv(os.path.join(data_dir, 'SOC_OCV_MFCTT_2019.csv'), sep='\t')
training_data_0 = pd.read_csv(os.path.join(data_dir, 'Model_Training_Data_0.csv'))
training_data_20 = pd.read_csv(os.path.join(data_dir, 'Model_Training_Data_20.csv'))
training_data_40 = pd.read_csv(os.path.join(data_dir, 'Model_Training_Data_40.csv'))

# %%
ref_SOC = SOC_OCV_data['SOC'].values                   # unit in %
ref_OCV = SOC_OCV_data['Ecell/V'].values               # unit in V
SOC_levels = np.arange(0.9, 0.1, -0.1)
SOC_from_idx_map = {i: SOC_levels[i] for i in range(8)}  # 8 SOC levels
temp_from_idx_map = {0: '$0^oC$', 1: '$20^oC$', 2: '$40^oC$'}  # 3 temperature level


def pad_time(t, max_length):
    N = len(t)
    if N == max_length:
        return t
    interval = t[-1] - t[-2]
    padded_t = np.pad(t, (0, max_length - N), mode='constant', constant_values=(0))
    padded_t[N - max_length:] = np.arange(t[-1] + interval, t[-1] + (max_length-len(t)+1) * interval, interval)
    
    return padded_t

max_length = np.max([len(training_data_0), len(training_data_20), len(training_data_40)])
t = [pad_time(training_data_0['Time (s)'].values, max_length), 
     pad_time(training_data_20['Time (s)'].values, max_length), 
     pad_time(training_data_40['Time (s)'].values, max_length)]
I = [np.pad(training_data_0['Current (A)'], (0, max_length - len(training_data_0)), mode='edge'),
     np.pad(training_data_20['Current (A)'], (0, max_length - len(training_data_20)), mode='edge'),
     np.pad(training_data_40['Current (A)'], (0, max_length - len(training_data_40)), mode='edge')]
V_actual = [np.pad(training_data_0['Voltage (V)'], (0, max_length - len(training_data_0)), mode='edge'),
            np.pad(training_data_20['Voltage (V)'], (0, max_length - len(training_data_20)), mode='edge'),
            np.pad(training_data_40['Voltage (V)'], (0, max_length - len(training_data_40)), mode='edge')]
t = np.array(t)                            # unit in s
I = -np.array(I)                           # unit in A
V_actual = np.array(V_actual)              # unit in V

# %%
which_temp = 0  # 0 if 0 degC, 1 if 20 degC, 2 if 40 degC
_, ax = plt.subplots(figsize=(10, 6))
ax.plot(t[which_temp], V_actual[which_temp])
ax.set_xlim([0, t[which_temp, -1]])
ax.set_xlabel('Time (s)')
ax.set_ylabel('Voltage (V)')
ax.grid()

_, ax = plt.subplots(figsize=(10, 6))
ax.plot(t[which_temp], I[which_temp])
ax.set_xlim([0, t[which_temp, -1]])
ax.set_xlabel('Time (s)')
ax.set_ylabel('Current (A)')
ax.grid()

plt.show()

# %% [markdown]
# ## Splitting Pulses
#
# The idx arrays now have shapes of [3, 8, 8], i.e., [temperatures, SOCs, Current]

# %%
idx_pulse_start = np.ndarray((3, 8, 8), dtype='int')
idx_pulse_end = np.ndarray((3, 8, 8), dtype='int')

for i in range(3):
    # shift to left by one index (now i is equivalent to i+1)
    I_shifted = np.concatenate((I[i, 1:], [0]))
    idx_start = np.flatnonzero((I[i] == 0) & (np.abs(I_shifted) > 1))
    idx_end = np.flatnonzero((np.abs(I[i]) > 1) & (I_shifted == 0)) + 1
    
    # if there are less than 8*8=64 points, pad with the last value to size 64
    # (because 0 deg has only 6 pulses at the last SOC)
    idx_start = np.pad(idx_start, (0, 64 - len(idx_start)), mode='edge')
    idx_end = np.pad(idx_end, (0, 64 - len(idx_end)), mode='edge')

    # reshape to 8 x 8 matrix, where rows correspond to each SOC value and
    #                                cols correspond to each pulse with different current
    idx_pulse_start[i] = idx_start.reshape(8, 8)
    idx_pulse_end[i] = idx_end.reshape(8, 8)

# %%
which_temp = 0
which_SOC = 4
which_pulse = 7
_ = plot_pulses(t, I, V_actual, idx_pulse_start, idx_pulse_end,
                which_SOC, which_pulse, show_current=True, temperature=which_temp)

# %% [markdown]
# Find index of steady-state voltage for each pulse:

# %%
idx_Vss = find_Vss_pos(t, V_actual, idx_pulse_start, idx_pulse_end)

# %%
# check all steady state:
show_temp = 0
for show_SOC in np.arange(1, 9):
    show_pulse = 'all'
    _ = plot_pulses(t, I, V_actual, idx_pulse_start, idx_pulse_end,
                    show_SOC, show_pulse, idx_Vss, show_current=False, temperature=show_temp)

# %% [markdown]
# ## Parametrisation

# %%
R0_tab, R1_tab, C1_tab, I_peaks, d_I, d_Vinf = para_RC(t, I, V_actual, idx_pulse_end, idx_Vss)
C1_const = read_fit_res(fit_res_dir, 'C1')  # from part 2a
print('C1 constant: ', C1_const)

# Visualisation:
rows = pd.MultiIndex.from_product([['%d%%' % (SOC_from_idx_map[i]*100) for i in range(8)],
                                   np.arange(1, 9)],
                                   names=['SOC', 'Pulse'])

# df0 = pd.DataFrame({'$I$ $(A)$': I_peaks[0].flatten(),
#                     '$R_0$ $(\Omega)$': R0_tab[0].flatten(),
#                     '$R_1$ $(\Omega)$': R1_tab[0].flatten(),
#                     '$C_1$ $(F)$': np.round(C1_const, 1)}, index=rows)
df0 = pd.DataFrame({'$R_0$ $(\Omega)$': np.round(R0_tab[0], 4).flatten(),
                    '$R_1$ $(\Omega)$': np.round(R1_tab[0], 4).flatten()}, index=rows)
df0.iloc[-2:] = np.nan  # only 6 pulses here

df20 = pd.DataFrame({'$R_0$ $(\Omega)$': np.round(R0_tab[1], 4).flatten(),
                     '$R_1$ $(\Omega)$': np.round(R1_tab[1], 4).flatten()}, index=rows)

df40 = pd.DataFrame({'$R_0$ $(\Omega)$': np.round(R0_tab[2], 4).flatten(),
                     '$R_1$ $(\Omega)$': np.round(R1_tab[2], 4).flatten()}, index=rows)

# For display:
table1 = df0.to_html()
table2 = df20.to_html()
table3 = df40.to_html()

# Concatenate the HTML tables horizontally
html = '<table style="display:inline-block;"><tr><th>T = 0 degC</th></tr><tr><td>{0}</td></tr></table>'.format(table1)
html += '<table style="display:inline-block;"><tr><th>T = 20 degC</th></tr><tr><td>{0}</td></tr></table>'.format(table2)
html += '<table style="display:inline-block;"><tr><th>T = 40 degC</th></tr><tr><td>{0}</td></tr></table>'.format(table3)
display(HTML(html))
# Out:
# C1 constant:  1348.8167320601592
# <table style="display:inline-block;"><tr><th>T = 0 degC</th></tr><tr><td><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>$R_0$ $(\Omega)$</th>
#       <th>$R_1$ $(\Omega)$</th>
#     </tr>
#     <tr>
#       <th>SOC</th>
#       <th>Pulse</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="8" valign="top">90%</th>
#       <th>1</th>
#       <td>0.0424</td>
#       <td>0.0176</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0416</td>
#       <td>0.0224</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0408</td>
#       <td>0.0162</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0416</td>
#       <td>0.0208</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.0375</td>
#       <td>0.0142</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.0400</td>
#       <td>0.0217</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.0326</td>
#       <td>0.0123</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.0385</td>
#       <td>0.0272</td>
#     </tr>
#     <tr>
#       <th rowspan="8" valign="top">80%</th>
#       <th>1</th>
#       <td>0.0424</td>
#       <td>0.0184</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0424</td>
#       <td>0.0208</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0410</td>
#       <td>0.0164</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0412</td>
#       <td>0.0200</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.0378</td>
#       <td>0.0139</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.0397</td>
#       <td>0.0202</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.0331</td>
#       <td>0.0118</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.0380</td>
#       <td>0.0255</td>
#     </tr>
#     <tr>
#       <th rowspan="8" valign="top">70%</th>
#       <th>1</th>
#       <td>0.0424</td>
#       <td>0.0180</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0424</td>
#       <td>0.0200</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0408</td>
#       <td>0.0164</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0404</td>
#       <td>0.0188</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.0376</td>
#       <td>0.0136</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.0392</td>
#       <td>0.0192</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.0332</td>
#       <td>0.0113</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.0375</td>
#       <td>0.0237</td>
#     </tr>
#     <tr>
#       <th rowspan="8" valign="top">60%</th>
#       <th>1</th>
#       <td>0.0436</td>
#       <td>0.0144</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0431</td>
#       <td>0.0200</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0422</td>
#       <td>0.0130</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0419</td>
#       <td>0.0192</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.0389</td>
#       <td>0.0115</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.0402</td>
#       <td>0.0200</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.0342</td>
#       <td>0.0107</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.0380</td>
#       <td>0.0247</td>
#     </tr>
#     <tr>
#       <th rowspan="8" valign="top">50%</th>
#       <th>1</th>
#       <td>0.0428</td>
#       <td>0.0132</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0432</td>
#       <td>0.0168</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0416</td>
#       <td>0.0128</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0416</td>
#       <td>0.0168</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.0387</td>
#       <td>0.0121</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.0397</td>
#       <td>0.0175</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.0345</td>
#       <td>0.0117</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.0377</td>
#       <td>0.0222</td>
#     </tr>
#     <tr>
#       <th rowspan="8" valign="top">40%</th>
#       <th>1</th>
#       <td>0.0440</td>
#       <td>0.0136</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0432</td>
#       <td>0.0168</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0430</td>
#       <td>0.0136</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0420</td>
#       <td>0.0168</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.0397</td>
#       <td>0.0135</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.0405</td>
#       <td>0.0172</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.0353</td>
#       <td>0.0135</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.0385</td>
#       <td>0.0218</td>
#     </tr>
#     <tr>
#       <th rowspan="8" valign="top">30%</th>
#       <th>1</th>
#       <td>0.0472</td>
#       <td>0.0184</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0463</td>
#       <td>0.0200</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0458</td>
#       <td>0.0188</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0452</td>
#       <td>0.0192</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.0417</td>
#       <td>0.0185</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.0432</td>
#       <td>0.0195</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.0327</td>
#       <td>0.0224</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.0427</td>
#       <td>0.0250</td>
#     </tr>
#     <tr>
#       <th rowspan="8" valign="top">20%</th>
#       <th>1</th>
#       <td>0.0500</td>
#       <td>0.0312</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0488</td>
#       <td>0.0272</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0472</td>
#       <td>0.0298</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0468</td>
#       <td>0.0232</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.0424</td>
#       <td>0.0287</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.0437</td>
#       <td>0.0220</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table></td></tr></table><table style="display:inline-block;"><tr><th>T = 20 degC</th></tr><tr><td><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>$R_0$ $(\Omega)$</th>
#       <th>$R_1$ $(\Omega)$</th>
#     </tr>
#     <tr>
#       <th>SOC</th>
#       <th>Pulse</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="8" valign="top">90%</th>
#       <th>1</th>
#       <td>0.0240</td>
#       <td>0.0080</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0160</td>
#       <td>0.0160</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0200</td>
#       <td>0.0100</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0200</td>
#       <td>0.0120</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.0200</td>
#       <td>0.0080</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.0200</td>
#       <td>0.0100</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.0190</td>
#       <td>0.0080</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.0200</td>
#       <td>0.0125</td>
#     </tr>
#     <tr>
#       <th rowspan="8" valign="top">80%</th>
#       <th>1</th>
#       <td>0.0200</td>
#       <td>0.0080</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0160</td>
#       <td>0.0160</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0200</td>
#       <td>0.0100</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0200</td>
#       <td>0.0120</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.0200</td>
#       <td>0.0080</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.0200</td>
#       <td>0.0100</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.0185</td>
#       <td>0.0075</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.0200</td>
#       <td>0.0125</td>
#     </tr>
#     <tr>
#       <th rowspan="8" valign="top">70%</th>
#       <th>1</th>
#       <td>0.0200</td>
#       <td>0.0120</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0160</td>
#       <td>0.0160</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0180</td>
#       <td>0.0100</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0200</td>
#       <td>0.0080</td>
#     </tr>
#     <tr>
#       <th>5</

# %%
idx_25 = np.where(np.abs(I_peaks[0, 0]-(-2.5)) < 0.01)[0][0]

T_plot = [0, 20, 40]

C1_90 = C1_tab[:, 0, idx_25]
C1_60 = C1_tab[:, 3, idx_25]
C1_30 = C1_tab[:, 6, idx_25]

fig, ax = plt.subplots()
ax.plot(T_plot, C1_90, '.', label='SOC = 90%', markersize=10)
ax.plot(T_plot, C1_60, '.', label='SOC = 60%', markersize=10)
ax.plot(T_plot, C1_30, '.', label='SOC = 30%', markersize=10)

ax.legend()
ax.grid()

ax.set_xlabel('Temperature ($\degree C$)')
ax.set_ylabel('$C_1 (F)$')
ax.set_ylim([500, 3500])
plt.show()

fig.savefig('Figures/Part 2/2c_C1_-2.5A_vs_T.eps', format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Part 2b
#
# Plot $R_0$ at $60\%$ SOC as a function of temperature.

# %%
R0_true = R0_tab[:, :, 4]
R0_true = np.mean(R0_true, axis=1)

T_fit = [0, 20, 40]

fig, ax = plt.subplots()
ax.plot(T_fit, R0_true, 'b.', markersize=10)
ax.set_xlabel('Temperature ($^oC$)')
ax.set_ylabel('R0 ($\Omega$)')
# ax.set_title('$R_0$ at $60\%$ SOC as a function of temperature')
ax.grid()
plt.show()

fig.savefig('Figures/Part 2/2b_R0_60SOC_vs_T.eps', format='eps')

# %% [markdown]
# Fit R0 at $60\%$ SOC to the Arrhenius Equation as a function of temperature.

# %%
# Define the Arrhenius Equation
T0 = 20
R0_T0 = np.mean(R0_tab[1, 3, :])
def Arrhenius(T_fit, E):
    return R0_T0 * np.exp(- E/8.3145 * (1/(T_fit+273.15) - 1/(T0+273.15)))

x = T_fit
y_true = R0_true
my_func = Arrhenius

popts, x_plot, y_pred = fit_RC(x, y_true, my_func)

# Print the fitted parameters
print('Fitted parameters:')
print('E =', popts[0])
print('\nConstants:')
print('R =', 8.3145)
print('T0 =', T0)

fig, ax = plt.subplots()
# Plot the data and the fitted function
ax.plot(x, y_true, 'b.', label='true data', linewidth=1.2)
ax.plot(x_plot, y_pred, 'r-', label='fitted', linewidth=1.2)
ax.legend()
ax.set_xlabel('Temperature ($^oC$)')
ax.set_ylabel('R0 ($\Omega$)')
# ax.set_title('Arrhenius Equation fitted on R0 at $60\%$ SOC')
ax.grid()
plt.show()

fig.savefig('Figures/Part 2/2b_R0_fit_Arrhenius.eps', format='eps')
# Out:
# Fitted parameters:
# E = -21814.06047913003
#
# Constants:
# R = 8.3145
# T0 = 20
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
info = {'R0_T0': R0_T0,
        'E': popts[0]}

with open(os.path.join(fit_res_dir, 'R0.json'), "w") as outfile:
    json.dump(info, outfile)

# %% [markdown]
# ## Part 2c

# %% [markdown]
# ### Step a
#
# Plot the value for $R_1$ at $0^oC$ and $-2.5A$ as a function of SOC.

# %%
idx_25 = np.where(np.abs(I_peaks[0, 0]-(-2.5)) < 0.01)[0][0]
SOC_plot = np.arange(0.9, 0.1, -0.1)
R1_plot = R1_tab[0, :, idx_25]

fig, ax = plt.subplots()
ax.plot(SOC_plot*100, R1_plot, 'b.', markersize=10)
ax.set_xlabel('SOC (%)')
ax.set_ylabel('R1 ($\Omega$)')
# ax.set_title('$R_1$ at $0^oC$ and $-2.5A$ as a function of SOC')
ax.grid()
plt.show()
fig.savefig('Figures/Part 2/2c_R1_25A_vs_SOC.eps', format='eps')

# %% [markdown]
# ### Step c
#
# Plot the value for $R_1$ at $60\%$ SOC and $-2.5A$ as a function of temperature.

# %%
idx_25 = np.where(np.abs(I_peaks[0, 0]-(-2.5)) < 0.01)[0][0]
T_fit = [0, 20, 40]
R1_true = R1_tab[:, 3, idx_25]

fig, ax = plt.subplots()
ax.plot(T_fit, R1_true, 'b.', markersize=10)
ax.set_xlabel('Temperature ($^oC$)')
ax.set_ylabel('R1 ($\Omega$)')
ax.grid()
# ax.set_title('$R_1$ at $60\%$ SOC and $-2.5A$ as a function of temperature')
plt.show()
fig.savefig('Figures/Part 2/2c_R1_60_SOC_25A_vs_T.eps', format='eps')

# %% [markdown]
# ### Step d
#
# Fit R1 at $60\%$ SOC and $-2.5A$ to the Arrhenius Equation as a function of temperature.

# %%
T0 = 20
R1_T0 = R1_tab[1, 3, idx_25]
def Arrhenius(T_fit, E):
    return R1_T0 * np.exp(- E/8.3145 * (1/(T_fit+273.15) - 1/(T0+273.15)))

x = T_fit
y_true = R1_true
my_func = Arrhenius
popts, x_plot, y_pred = fit_RC(x, y_true, my_func)

print('Fitted parameters:')
print('E:', popts[0])
print('\nConstants:')
print('R:', 8.3145)
print('T0:', T0)

fig, ax = plt.subplots()
ax.plot(x, y_true, 'b.', label='true data', linewidth=1.2)
ax.plot(x_plot, y_pred, 'r-', label='fitted', linewidth=1.2)
ax.legend()
ax.set_xlabel('Temperature ($^oC$)')
ax.set_ylabel('R1 ($\Omega$)')
ax.grid()
# ax.set_title('Arrhenius Equation fitted on $R_1$ at $60\%$ SOC and $-2.5A$')
plt.show()
fig.savefig('Figures/Part 2/2c_R1_fit_Arrhenius.eps', format='eps')
# Out:
# Fitted parameters:
# E: -15813.772998513376
#
# Constants:
# R: 8.3145
# T0: 20
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
info = {'E': popts[0]}

with open(os.path.join(fit_res_dir, 'R1_arr.json'), "w") as outfile:
    json.dump(info, outfile)

# %% [markdown]
# ### Step e + f
#
# Plot the value of $R_1$ at $-2.5A$ as a function of temperature, at $30\%$ SOC and $90\%$ separately.
#
# And fit them into the equation obtained from step d.

# %%
fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(13, 4))

# SOC = 30%
R1_T0 = R1_tab[1, 6, idx_25]
def Arrhenius(T_fit, E):
    return R1_T0 * np.exp(- E/8.3145 * (1/(T_fit+273.15) - 1/(T0+273.15)))
R1_true = R1_tab[:, 6, idx_25]
y_true = R1_true
y_pred = Arrhenius(x_plot, *popts)

ax1.plot(x, y_true, 'b.', label='true data', linewidth=1.2)
ax1.plot(x_plot, y_pred, 'r-', label='fitted', linewidth=1.2)  # same with 60% SOC
ax1.legend()
ax1.set_xlabel('Temperature ($^oC$)')
ax1.set_ylabel('R1 ($\Omega$)')
# ax1.set_title('Predicted $R_1$ at $30\%$ SOC and $-2.5A$ as a function of temperature')
ax1.set_title('$30\%$ SOC')
ax1.grid()

# SOC = 90%
R1_T0 = R1_tab[1, 0, idx_25]
def Arrhenius(T_fit, E):
    return R1_T0 * np.exp(- E/8.3145 * (1/(T_fit+273.15) - 1/(T0+273.15)))
y_pred = Arrhenius(x_plot, *popts)

ax2.plot(x, y_true, 'b.', label='true data', linewidth=1.2)
ax2.plot(x_plot, y_pred, 'r-', label='fitted', linewidth=1.2)  # same with 60% SOC
ax2.set_xlabel('Temperature ($^oC$)')
ax2.set_ylabel('R1 ($\Omega$)')
ax2.grid()
# ax2.set_title('Predicted $R_1$ at $90\%$ SOC and $-2.5A$ as a function of temperature')
ax2.set_title('$90\%$ SOC')

plt.show()
fig.savefig('Figures/Part 2/2c_R1_pred_3090SOC.eps', format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Equation 4
#
# Create a new function for $R_1$ that includes both the current and temperature dependence.
#
# The first step is to take the small bumps before every 8 pulses, as we did in part 2a.

# %%
idx_bump_start = np.ndarray((3, 8), dtype='int')
idx_bump_end = np.ndarray((3, 8), dtype='int')


for i in range(3):
    # shift to left by one index (now i is equivalent to i+1)
    I_shifted = np.concatenate((I[i, 1:], [0]))
    idx_start = np.flatnonzero((I[i] == 0) & (np.abs(I_shifted) < 1) & (np.abs(I_shifted) > 0.2))
    idx_end = np.flatnonzero((np.abs(I[i]) < 1) & (np.abs(I[i]) > 0.2) & (I_shifted == 0)) + 1

    idx_bump_start[i] = idx_start
    idx_bump_end[i] = idx_end
    
idx_bump_Vss = find_Vss_pos(t, V_actual, idx_bump_start, idx_bump_end, for_bump=True, idx_for_bump=idx_pulse_start)

# %%
# check all steady state position for bumps:
# show_temp = 2
# show_pulse = 1
# for show_SOC in np.arange(1, 9):
#     _ = plot_pulses(t, I, V_actual, np.repeat(idx_bump_start.reshape(3, -1, 1), 8, axis=2), 
#            np.repeat(idx_bump_end.reshape(3, -1, 1), 8, axis=2),
#            show_SOC, show_pulse, np.repeat(idx_bump_Vss.reshape(3, -1, 1), 8, axis=2), 
#            temperature=show_temp)

# %%
R1_bumps = np.ndarray((3, 8))
I_bumps = np.ndarray((3, 8))

for i in range(3):
    _, R1_bumps[i], _, I_bumps[i], _, _ = para_RC(t[i], I[i], V_actual[i], idx_bump_end[i], idx_bump_Vss[i])

# %%
I_fit = np.append(I_peaks[:, 3, :], I_bumps[:, 3].reshape(3, 1), axis=1)
T_fit = np.array([0, 20, 40])
T_fit = np.ones((3, 9)) * T_fit[:, np.newaxis]
R1_true =  np.append(R1_tab[:, 3, :], R1_bumps[:, 3].reshape(3, 1), axis=1)

# %% [markdown]
# Fit original Equation:

# %%
def Arrhenius(X, R1_0AT0):
    _, b, c, _ = read_fit_res(fit_res_dir, 'R1_gauss')
    E = read_fit_res(fit_res_dir, 'R1_arr')
    
    I_fit, T_fit = X
    T_fitK = T_fit + 273.15
    T0 = 20 + 273.15
    
    R1 = R1_0AT0 * np.exp(-(I_fit - b)**2 / c) * \
            np.exp(- E/8.3145 * (1/T_fitK - 1/T0))
    return R1

X = (I_fit.flatten(), T_fit.flatten())
y_true = R1_true.flatten()
my_func = Arrhenius
popts, _ = curve_fit(my_func, X, y_true)

print('Fitted parameters:')
print('R1_0AT0 =', popts[0])
print('\nConstants:')
print('R =', 8.3145)
print('T0 =', T0)

# at different temperature:
T_plots = [0, 20, 40]
for i in range(3):
    T_plot = T_plots[i]
    x_fit = I_fit[i]
    y_true = R1_true[i]
    x_plot = np.linspace(np.min(x_fit), np.max(x_fit), 500)
    y_pred = my_func((x_plot, T_plot), *popts)

    fig, ax = plt.subplots()
    ax.plot(x_fit, y_true, 'b.', label='true data', linewidth=1.2)
    ax.plot(x_plot, y_pred, 'r-', label='fitted', linewidth=1.2)
    ax.legend()
    ax.set_xlabel('Current (A)')
    ax.set_ylabel('R1 ($\Omega$)')
    ax.grid()
#     ax.set_title('Final Equation fitted on $R_1$ at $60\%$ SOC\n$T={}^oC$'.format(T_plot))
    ax.set_title('$T={}^oC$'.format(T_plot))
    plt.show()
    fig.savefig('Figures/Part 2/2c_R1_fit_final_wo_offset_T{}.eps'.format(T_plot), format='eps')
# Out:
# Fitted parameters:
# R1_0AT0 = 0.06636019999900622
#
# Constants:
# R = 8.3145
# T0 = 20
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Add offset:

# %%
def Arrhenius(X, R1_0AT0):
    _, b, c, d = read_fit_res(fit_res_dir, 'R1_gauss')
    E = read_fit_res(fit_res_dir, 'R1_arr')

    I_fit, T_fit = X
    T_fitK = T_fit + 273.15
    T0 = 20 + 273.15

    R1 = R1_0AT0 * (np.exp(-(I_fit - b)**2 / c)) * \
            np.exp(- E/8.3145 * (1/T_fitK - 1/T0)) + d
    
    return R1


X = (I_fit.flatten(), T_fit.flatten())
y_true = R1_true.flatten()
my_func = Arrhenius
popts, _ = curve_fit(my_func, X, y_true)

print('Fitted parameters:')
print('R1_0AT0:', popts[0])
print('\nConstants:')
print('R =', 8.3145)
print('T0 =', T0)

# at different temperature:
T_plots = [0, 20, 40]
for i in range(3):
    T_plot = T_plots[i]
    x_fit = I_fit[i]
    y_true = R1_true[i]
    x_plot = np.linspace(np.min(x_fit), np.max(x_fit), 500)
    y_pred = my_func((x_plot, T_plot), *popts)

    fig, ax = plt.subplots()
    ax.plot(x_fit, y_true, 'b.', label='true data', linewidth=1.2)
    ax.plot(x_plot, y_pred, 'r-', label='fitted', linewidth=1.2)
    ax.legend()
    ax.set_xlabel('Current (A)')
    ax.set_ylabel('R1 ($\Omega$)')
    ax.grid()
#     ax.set_title('Final Equation fitted on $R_1$ at $60\%$ SOC\n$T={}^oC$'.format(T_plot))
    ax.set_title('$T={}^oC$'.format(T_plot))
    plt.show()
    fig.savefig('Figures/Part 2/2c_R1_fit_final_with_offset_T{}.eps'.format(T_plot), format='eps')
# Out:
# Fitted parameters:
# R1_0AT0: 0.05837129944957861
#
# Constants:
# R = 8.3145
# T0 = 20
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
info = {'R1_0AT0': popts[0]}

with open(os.path.join(fit_res_dir, 'R1.json'), "w") as outfile:
    json.dump(info, outfile)
